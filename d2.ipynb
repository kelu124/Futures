# %%
# %load_ext autoreload
# %autoreload 2

# %%
from futures.llm import LLM
from futures.futurist import Futurist
from futures.db import DB
from futures.substack import SubstackManager

import pandas as pd

# %%
sm = SubstackManager()

# %%
pages = sm.download_pages()

# %%
sm.getPages() # 25seconds
# Out:
# # Substack manager starts
# - Substack manager:  20250223 exists
# - Substack manager:  20250209 exists
# - Substack manager:  20250105 exists
# - Substack manager:  20250302 exists
# - Substack manager:  20250119 exists
# - Substack manager:  20241215 exists
# - Substack manager:  20241222 exists
# - Substack manager:  20241229 exists
# - Substack manager:  20250216 exists
# - Substack manager:  20250112 exists
# - Substack manager:  20250202 exists
# - Substack manager:  20250126 exists
# # Saving links from the substack pages

# %%
# Let's initialise our AI and our futurist
llm = LLM(datastore="data/")
f = Futurist(llm)

# %%
nb_articles = 30000
# Creating seeds
f.createSeeds(n=nb_articles)
# Creating metas
f.moreIntel(n=nb_articles)
# Creating metas
f.doMeta(n=nb_articles)
# Out:
# # Doing get_weaksignals processing
# IDs identifiees 	 2366 	 get_weaksignals
# # Doing get_summary processing
# IDs identifiees 	 2366 	 get_summary
# # Doing get_emergingissues processing
# IDs identifiees 	 2366 	 get_emergingissues
# # Doing get_emergingtechnologies processing
# IDs identifiees 	 2364 	 get_emergingtechnologies
# # Doing get_emergingbehaviors processing
# IDs identifiees 	 2366 	 get_emergingbehaviors
# # Doing metas processing
#                   type                                             themes  \
# 0            blog post  CHAT-GPT, Knowledge Graph, Mermaid, Entity Rel...
# 1            blog post  foresight,signals,signal processing,ChatGPT,te...
# 2            blog post  book summary,leadership,finite and infinite games
# 3            blog post  fighter pilots,dogfighting,OODA loop,agency,se...
# 4                 news  wind power, cargo shipping, decarbonisation, e...
# ...                ...                                                ...
# 2431  research article  robotics, neuroscience, human augmentation, br...
# 2432     error message                      404 error, website navigation
# 2433              news  AI, machine learning, data scarcity, technolog...
# 2434           article  automotive industry, corporate fraud, short se...
# 2435         blog post  paper maps, digital navigation, millennials, g...
#
#         category                                           keywords  \
# 0     technology  Knowledge Graph, Mermaid, Entity Relationship ...
# 1     technology  foresight, signals, signal processing, ChatGPT...
# 2       business  The Infinite Game,Simon Sinek,leadership,infin...
# 3        science  John Boyd,dogfight,cybernetic system,mindfulne...
# 4     technology  wind-powered ship, Cargill, WindWings, carbon ...
# ...          ...                                                ...
# 2431     science  robotic limbs, brain control, human enhancemen...
# 2432      others                  404, error, not found, navigation
# 2433  technology  AI chatbots, training data, machine learning, ...
# 2434  technology  Nikola, Trevor Milton, Hindenburg Research, co...
# 2435  technology  paper maps, Google Maps, navigation, millennia...
#
#                                    src                                path  \
# 0     03920ec25887e9533ca00b84a67db724  ./substack_cache/substack/20230701
# 1     d3ca03ec9e48516fa3d82a78cf2d61c0  ./substack_cache/substack/20230701
# 2     54d1f8c7676710e22272e828c43e9934  ./substack_cache/substack/20230701
# 3     fb85833357a95b5d05462466cffa6fbd  ./substack_cache/substack/20230701
# 4     17a6704a82824be2f5910ebceee7ec75  ./substack_cache/substack/20290911
# ...                                ...                                 ...
# 2431  faad51d1f885af1db9dee5e5ce52b46e  ./substack_cache/substack/20230205
# 2432  a98477873581dec082fb879c3f7904e1  ./substack_cache/substack/20230205
# 2433  85ca2591053db7e76f0d273c63fee1b0  ./substack_cache/substack/20230205
# 2434  fcd0d8f2b79472618822acb86fccea35  ./substack_cache/substack/20230205
# 2435  70c5542aafd26bb4b293f2bfaa80c61d  ./substack_cache/substack/20230205
#
#                                                     url  \
# 0     b'https://medium.com/openlink-software-blog/ho...
# 1     b'https://medium.com/@christian.graham_49279/u...
# 2     b'https://en.wikipedia.org/wiki/The_Infinite_G...
# 3     b'https://subconscious.substack.com/p/tools-fo...
# 4     b'https://www.bbc.com/news/technology-66543643...
# ...                                                 ...
# 2431    b'https://spectrum.ieee.org/human-augmentation'
# 2432  b'https://metaphysic.ai/ai-hollywood-miramax-h...
# 2433  b'https://www.newscientist.com/article/2353751...
# 2434  b'https://nymag.com/intelligencer/2022/01/nath...
# 2435  b'https://www.wsj.com/articles/why-paper-map-s...
#
#                                                 content    LEN    origin
# 0     HowTo — Using CHAT-GPT to generate a Knowledge...  27092   27092.0
# 1     Using ChatGPT for foresight: Signal processing...   4370    4370.0
# 2     The Infinite Game\n| Author | Simon Sinek |\n|...   3869    3869.0
# 3     How does a fighter pilot win a dogfight? If yo...   6735    6735.0
# 4     Pioneering wind-powered cargo ship sets sail\n...   5276    5276.0
# ...                                                 ...    ...       ...
# 2431  Roboticists Want to Give You a Third Arm\nUnus...  18549  20230205
# 2432                                  404\nGo back home     16  20230205
# 2433  AI chatbots could hit a ceiling after 2026 as ...    660  20230205
# 2434  This article was featured in One Great Story, ...  39810  20230205
# 2435  Forget Google Maps: Why Paper Map Sales Are Bo...   1090  20230205
#
# [2436 rows x 10 columns]

# %%
pd.read_parquet("data/stories.parquet.gzip")
# Out:
#                    src                                       title  \
# 0             20250302                       The Pickle Revolution
# 1             20250223                         Threads of Tomorrow
# 2             20230927                Navigating the Jangled Nexus
# 3             20230612              Harvesting Bytes in Snailbrook
# 4             20230616               Chaotic Symphony of the Green
# ..                 ...                                         ...
# 129           20240609  Kneading Humanity: A Recipe for Connection
# 130           20240128                      Byte-Sized Innovations
# 131           20220212               "Ballooning into Imagination"
# 132           20241103               Mushrooms in the Digital Soil
# 133  virtualcolleagues               Mushrooms in the Digital Soil
#
#                                                  story
# 0    The last vestiges of human touch in the sprawl...
# 1    The air hummed with the promises of the future...
# 2    “The AI consultant was three seconds away from...
# 3    In Snailbrook, Texas—a quaint town, where peop...
# 4    In a world where digital landscapes blurred th...
# ..                                                 ...
# 129  Jean had taken to baking bread in her dim kitc...
# 130  The digital rain fell like tiny coding errors ...
# 131  Beneath the fluttering banners of an unremarka...
# 132  Adrian’s job had become a magnificent balancin...
# 133  Adrian’s job had become a magnificent balancin...
#
# [134 rows x 3 columns]

# %%
f.writeAllStories()

# %% [markdown]
# # Using the vectorDB

# %%
db= DB(llm)

# %%
vectordb = db.createDB()
# Out:
# # VectorDB: continue on the DB
# - VectorDB:  3212 elements already stored.
# - VectorDB: adding 2366 documents.

# %%
from futures.pages import PagesWriter

# %%
pw = PagesWriter(db=db)

# %%
df, signals = pw.createPages_metaPrep(longtest=False)

# %%
pw.createPages()
pw.createPagesIndex()
