# %%
# %load_ext autoreload
# %autoreload 2

# %%
from futures.llm import LLM
from futures.futurist import Futurist
from futures.db import DB
from futures.substack import SubstackManager

import pandas as pd

# %%
sm = SubstackManager()

# %%
pages = sm.download_pages()
# Out:
#                              file_name  \
# 0     a4efc4d42a3295e79bc6548f9849736b
# 1     ef44cb256854bbf303ad9cd0e262f0ec
# 2     5854e990e57fb229570c3dcd634328b1
# 3     34b2a200729dc9e1f9204bab09b20222
# 4     1098d7983c2bef34b8ed9679bb6a757b
# ...                                ...
# 3186  037aba804501ec9f75f8bb434b8a6c20
# 3187  0810cdb75f0d657c86d7b963b4a3fa3a
# 3188  e263c8fd10a043d8b52393f8cff19158
# 3189  382e9ebc1e518ee49e541da1e6b5f8af
# 3190  6e0e074e3fd0d29800b270beffb6d3f3
#
#                                                 content    origin    LEN
# 0     The Handoff to Bots\nSummary: Human population...  20250302   9435
# 1     A venture capital-backed “AI performance monit...  20250302   3064
# 2     WASHINGTON — Responses to the Elon Musk-direct...  20250302  11477
# 3     Partners book record profits while cutting 1,2...  20250302  10355
# 4     To continue, please click the box below to let...  20250223    478
# ...                                                 ...       ...    ...
# 3186  Learn In Public\nThe fastest way to learn\nswy...  20220717   9756
# 3187  Please switch to a supported browser to contin...  20220225    224
# 3188        Please enable JS and disable any ad blocker  20240121     43
# 3189  It’s been a frenetic six months since OpenAI i...  20230604   4654
# 3190  Every two weeks from March to November, Chris ...  20221127  18469
#
# [3191 rows x 4 columns]

# %%
sm.getPages() # 25seconds
# Out:
# # Substack manager starts
# - Substack manager:  20250202 exists
# - Substack manager:  20250119 exists
# - Substack manager:  20250216 exists
# - Substack manager:  20250209 exists
# - Substack manager:  20241222 exists
# - Substack manager:  20250126 exists
# - Substack manager:  20250105 exists
# - Substack manager:  20250112 exists
# - Substack manager:  20241229 exists
# - Substack manager:  20250223 exists
# - Substack manager:  20241215 exists
# - Substack manager:  20250302 exists
# # Saving links from the substack pages

# %%
# Let's initialise our AI and our futurist
llm = LLM(datastore="data/")
f = Futurist(llm)
# Out:
# /home/kelu/projets/Futures/futures/llm.py:26: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   self.underlying_embeddings = OpenAIEmbeddings()
# /home/kelu/projets/Futures/futures/llm.py:39: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   self.ai = ChatOpenAI(model=llm_fast)

# %%
nb_articles = 30000
# Creating seeds
f.createSeeds(n=nb_articles)
# Creating metas
f.moreIntel(n=nb_articles)
# Creating metas
f.doMeta(n=nb_articles)
# Out:
# # Doing get_weaksignals processing
# IDs identifiees 	 2366 	 get_weaksignals
# # Doing get_summary processing
# IDs identifiees 	 2366 	 get_summary
# # Doing get_emergingissues processing
# IDs identifiees 	 2366 	 get_emergingissues
# # Doing get_emergingtechnologies processing
# IDs identifiees 	 2360 	 get_emergingtechnologies
# * Saving to
# # Doing get_emergingbehaviors processing
# IDs identifiees 	 2366 	 get_emergingbehaviors

# %%
f.doMeta(n=nb_articles)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 f.doMeta(n=nb_articles)
#
# File ~/projets/Futures/futures/futurist.py:130, in Futurist.doMeta(self, n)
#     128 for _, row in dfContent[0:n].iterrows():
#     129     if not row["src"] in meta_init:
# --> 130         meta = pd.DataFrame([json.loads(self.ai.askFunctions("Extract the metatags of this text", row["content"], getMeta(), "get_meta"))])
#     131         meta["src"] = row["src"]
#     132         allMetas.append(meta)
#
# File ~/projets/Futures/futures/llm.py:69, in askFunctions(self, instructions, text, function, function_name)
#      61 def askFunctions(self, instructions, text, function, function_name):
#      62     messages = [
#      63         HumanMessage(content=f"""
#      64         ## Instructions
#      65         {instructions}
#      66
#      67         ## Text
#      68         {text}
# ---> 69         """)
#      70     ]
#      72     response = self.ai.invoke(
#      73         messages,
#      74         functions=function,
#      75         function_call={"name": function_name}
#      76     )
#      78     return response.additional_kwargs["function_call"]["arguments"]
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)
#     857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_community/chat_models/openai.py:476, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     470 message_dicts, params = self._create_message_dicts(messages, stop)
#     471 params = {
#     472     **params,
#     473     **({"stream": stream} if stream is not None else {}),
#     474     **kwargs,
#     475 }
# --> 476 response = self.completion_with_retry(
#     477     messages=message_dicts, run_manager=run_manager, **params
#     478 )
#     479 return self._create_chat_result(response)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_community/chat_models/openai.py:387, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     385 """Use tenacity to retry the completion call."""
#     386 if is_openai_v1():
# --> 387     return self.client.create(**kwargs)
#     389 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     391 @retry_decorator
#     392 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_base_client.py:1003, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1000 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1002 try:
# -> 1003     response = self._client.send(
#    1004         request,
#    1005         stream=stream or self._should_stream_response_body(request=request),
#    1006         **kwargs,
#    1007     )
#    1008 except httpx.TimeoutException as err:
#    1009     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.11/ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File /usr/lib/python3.11/ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
f.writeAllStories()
# Out:
# {'20250302': ['a4efc4d42a3295e79bc6548f9849736b', 'ef44cb256854bbf303ad9cd0e262f0ec', '5854e990e57fb229570c3dcd634328b1', '34b2a200729dc9e1f9204bab09b20222', 'fb4c4ce722b5eb99ab866cf06e4fd108', 'f3f7c111d85459c6aa1d719673cae79f', '6e3f2485c73c82df829017278920c2c1', '9638d336ad5b456ce289418433ecfacf', 'c5dfe9f6d4afa337164a4944b27ec79f', 'a7cc9315b5ebbac68fe654918a1da286', '1d88d1adb536215512bd7d3380493797', 'aa17441091514ac3081b8e57221f3fce', 'b20fb97f6ad12a6389468e434068e2ad', '8023fa9330f1bac7f56a3f586f3c4f8c', '8c75c19d84e0d4aa8e1d1ea0420313a0', '4b6f5abd8dea85056449fa9a6e7cc637', '32b15503bb9a88d3cb10661b71c47eb4', 'e14d5a2d51f4c178fed312dbbdf2ed05', '668e265ec4654109892bee400ea26d68', 'f41e885ef501d34e79b75bb8b77302f9', '1a16b10a8ac1a5aaee8307f42678976c', 'c88541648e74a1a161aa7fb97ac14e84', 'f37715918f2a05dcd3d4a3d9e93b4173', 'f53cb1cffdb2f65059c5c35524f68aea', '38530ee99559d7ed08c32f619bc1d429', '6269bb1ff221e959b7b02d367d989ab2', '346a6c6eae54990d5397bcb310b62c93', '843f4c657be90217ea0f2f0b6519a5c3', '4b9bf29ac9c09642bef612847f5b9223', '6faf47a39edb0613da27af18a3fc20c8'], '20250223': ['12c665a21f8c6930a28f7c56f3b79b19', '7a34820852cf03cbbdb1fb75ca3b629c', '4dc27c3427b9c3021d4a20603e51e516', '4a29bff5e6b05b4826468801ee240edb', '6bac89b8c5fdf1c1e33c8e1da193827a', '4c0323220b8e42ef6b79dd4d720ce80a', '6f7b4e8be445b769c44531f844aabe0f', '72ad2ad82a4064cc0219178869779cd8', 'fcae2605790df6386dcc1465cb294d83', '89c33ff05c7560194e8902922720afa5', '7497f712012e964266a440f7ff73974e', 'c0c7f3a02e89c04a227c3a467c10da68', '299248e05dbfb0ab57ae84fc170ee39a', 'b87b3329ddb8dd4710c7176258a84ff3', 'd06afe4260c7035e564077936d8556ff', '22b9f4fbbb1a4134de2f8a3412b08393', 'cd6a3016e9c9fa46f13d29ded245803a', '444c344c2d26b65197d1159129f2ec53', 'e44687e103abb436ad5980ac2d518f47', '26e385bfcd6784d024e3e49e8b04ce89', '2cce707eff428a7df3e97b43e696f71c', '3c27a71013ec18bf55a80ae739105bd7', 'f040875d7385a703680eb
', '09d755bf91d4fd4e1adf09d7ee1f4656', 'e0f6ae75e034df0a32044fe8a9075673', '8dfeb7f353bb51c54f0fbaeadf3ed292', '4b5e4f86651ce9d8c1f4d0ed6c13e384', '7eaef73ec22b42f1a0b0f4aa8b084a49', '191070a30a1d11509e1f783a0ca8e8e0'], '20230616': ['656239ad8ab36ce06ac4ee6258b5381d', '997c962feb825d066ca4dc6e4742e8a9', 'b75f2d908abb3ba97b7673a475bbf36b', 'de8c393b7b1395557948cb50d90de996', '9fd8c7460fe2d17a54694de66ebd64ca', 'f87bcfb74a4a1db0ac38bd573144fd59', '3002f8c37aa3a21ff809ef9530368f00', 'f057cce6610da90d071679647fbe3b88', 'aed94a25a5eda4f0d45a976a94a8c223', 'c6357a8ef791346fab1c951e0773476f', '2b2438cd827520a2dfdcffa094cc7fc3', 'db2690cf7530366ddf6f9606b830f782', '56f93e34024f9bf044f570856f99590f'], '20040714': ['c7d3021c1b6298e7c47bc455cd7d8391', '20e24f276ca807be7569424d8072a67e', '4a9a8581c9a752497d69047d62378dea', '2d27d6b4a321a16f49c2e77988a13246', '36fb34db6e6d559e27ceb9ff09d6f65b', '53c3e72c4d0a4687bf4652b5f6a5076a', '5cbf19bc5097424a9bd615c891be2a12', '5bc0c7ca523dae8640dcb7f6023f85fb', 'e4c05fa0d5dacdd8fbb7f4e0b70a32a0', '7a1441e130e80653c16eb4905eee4d20', '34fb411b34c997f52f550d855c864865'], '20220922': ['94960bd3c0ad4c594fd56651f4087128', 'f99fa5e02647a517b709d5b44f85fd5c', '53c5550484135e9581500f193d2e8 ...
# - Story for 20250302
# - Story not in  20250302
# - Story for 20250223
# - Story not in  20250223
# - Story for 20230927
# - Story not in  20230927
# - Story for 20230612
# - Story not in  20230612
# - Story for 20230616
# - Story not in  20230616
# - Story for 20040714
# - Story not in  20040714
# - Story for 20220922
# - Story not in  20220922
# - Story for 20240901
# - Story not in  20240901
# - Story for 20230108
# - Story not in  20230108
# - Story for 20220810
# - Story not in  20220810
# - Story for 20240728
# - Story not in  20240728
# - Story for 20250209
# - Story not in  20250209
# - Story for 20221031
# - Story not in  20221031
# - Story for 20230505
# - Story not in  20230505
# - Story for 20231111
# - Story not in  20231111
# - Story for 20231126
# - Story not in  20231126
# - Story for 20230423
# - Story not in  20230423
# - Story for 20230319
# - Story not in  20230319
# - Story for 20241124
# - Story not in  20241124
# - Story for 20250119
# - Story not in  20250119
# - Story for 20240428
# - Story not in  20240428
# - Story for 20241208
# - Story not in  20241208
# - Story for 20230819
# - Story not in  20230819
# - Story for 20240922
# - Story not in  20240922
# - Story for 20220118
# - Story not in  20220118
# - Story for 20240623
# - Story not in  20240623
# - Story for 20221218
# - Story not in  20221218
# - Story for 20230401
# - Story not in  20230401
# - Story for 20230115
# - Story not in  20230115
# - Story for 20220626
# - Story not in  20220626
# - Story for 20250216
# - Story not in  20250216
# - Story for 20230701
# - Story not in  20230701
# - Story for 20220128
# - Story not in  20220128
# - Story for 20230730
# - Story not in  20230730
# - Story for 20230303
# - Story not in  20230303
# - Story for 20221127
# - Story not in  20221127
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 f.writeAllStories()
#
# File ~/projets/Futures/futures/futurist.py:222, in writeAllStories(self)
#     220 def writeAllStories(self):
#     221     articles = self.getLinksPerArticle()
# --> 222     print(articles)
#     223     story = self.writeStory(articles)
#
# File ~/projets/Futures/futures/futurist.py:194, in Futurist.writeStory(self, ids)
#     192 prompt += "* You will use a style mix of Terry Pratchett and Philip K Dick:\n\n"+STYLE
#     193 prompt += "\n\nStill, your style needs to be simple and readable by a 20yo, and keep a simple writing style.\n\n"
# --> 194 prompt += "\n\n## Summaries of texts\n\n"+ context
#     195 story = self.ai.ask(prompt)
#     196 title = self.ai.ask("Give a title to the short story below. Don't use quotes or any accompanying text:\n\n"+story)
#
# File ~/projets/Futures/futures/llm.py:55, in LLM.ask(self, question)
#      54 def ask(self, question):
# ---> 55     answer = self.ai.invoke(question)
#      56     return json.loads(answer.model_dump_json())["content"]
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
#     290             run_name=config.get("run_name"),
#     291             run_id=config.pop("run_id", None),
#     292             **kwargs,
#     293         ).generations[0][0],
#     294     ).message
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:860, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     852 def generate_prompt(
#     853     self,
#     854     prompts: list[PromptValue],
#    (...)
#     857     **kwargs: Any,
#     858 ) -> LLMResult:
#     859     prompt_messages = [p.to_messages() for p in prompts]
# --> 860     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:690, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     687 for i, m in enumerate(messages):
#     688     try:
#     689         results.append(
# --> 690             self._generate_with_cache(
#     691                 m,
#     692                 stop=stop,
#     693                 run_manager=run_managers[i] if run_managers else None,
#     694                 **kwargs,
#     695             )
#     696         )
#     697     except BaseException as e:
#     698         if run_managers:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_community/chat_models/openai.py:476, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     470 message_dicts, params = self._create_message_dicts(messages, stop)
#     471 params = {
#     472     **params,
#     473     **({"stream": stream} if stream is not None else {}),
#     474     **kwargs,
#     475 }
# --> 476 response = self.completion_with_retry(
#     477     messages=message_dicts, run_manager=run_manager, **params
#     478 )
#     479 return self._create_chat_result(response)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/langchain_community/chat_models/openai.py:387, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     385 """Use tenacity to retry the completion call."""
#     386 if is_openai_v1():
# --> 387     return self.client.create(**kwargs)
#     389 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     391 @retry_decorator
#     392 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/resources/chat/completions/completions.py:879, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     837 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     838 def create(
#     839     self,
#    (...)
#     876     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     877 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     878     validate_response_format(response_format)
# --> 879     return self._post(
#     880         "/chat/completions",
#     881         body=maybe_transform(
#     882             {
#     883                 "messages": messages,
#     884                 "model": model,
#     885                 "audio": audio,
#     886                 "frequency_penalty": frequency_penalty,
#     887                 "function_call": function_call,
#     888                 "functions": functions,
#     889                 "logit_bias": logit_bias,
#     890                 "logprobs": logprobs,
#     891                 "max_completion_tokens": max_completion_tokens,
#     892                 "max_tokens": max_tokens,
#     893                 "metadata": metadata,
#     894                 "modalities": modalities,
#     895                 "n": n,
#     896                 "parallel_tool_calls": parallel_tool_calls,
#     897                 "prediction": prediction,
#     898                 "presence_penalty": presence_penalty,
#     899                 "reasoning_effort": reasoning_effort,
#     900                 "response_format": response_format,
#     901                 "seed": seed,
#     902                 "service_tier": service_tier,
#     903                 "stop": stop,
#     904                 "store": store,
#     905                 "stream": stream,
#     906                 "stream_options": stream_options,
#     907                 "temperature": temperature,
#     908                 "tool_choice": tool_choice,
#     909                 "tools": tools,
#     910                 "top_logprobs": top_logprobs,
#     911                 "top_p": top_p,
#     912                 "user": user,
#     913             },
#     914             completion_create_params.CompletionCreateParams,
#     915         ),
#     916         options=make_request_options(
#     917             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     918         ),
#     919         cast_to=ChatCompletion,
#     920         stream=stream or False,
#     921         stream_cls=Stream[ChatCompletionChunk],
#     922     )
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_base_client.py:1290, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1276 def post(
#    1277     self,
#    1278     path: str,
#    (...)
#    1285     stream_cls: type[_StreamT] | None = None,
#    1286 ) -> ResponseT | _StreamT:
#    1287     opts = FinalRequestOptions.construct(
#    1288         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1289     )
# -> 1290     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_base_client.py:967, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     964 else:
#     965     retries_taken = 0
# --> 967 return self._request(
#     968     cast_to=cast_to,
#     969     options=options,
#     970     stream=stream,
#     971     stream_cls=stream_cls,
#     972     retries_taken=retries_taken,
#     973 )
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/openai/_base_client.py:1003, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1000 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#    1002 try:
# -> 1003     response = self._client.send(
#    1004         request,
#    1005         stream=stream or self._should_stream_response_body(request=request),
#    1006         **kwargs,
#    1007     )
#    1008 except httpx.TimeoutException as err:
#    1009     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/projets/Futures/.venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.11/ssl.py:1263, in SSLSocket.recv(self, buflen, flags)
#    1259     if flags != 0:
#    1260         raise ValueError(
#    1261             "non-zero flags not allowed in calls to recv() on %s" %
#    1262             self.__class__)
# -> 1263     return self.read(buflen)
#    1264 else:
#    1265     return super().recv(buflen, flags)
#
# File /usr/lib/python3.11/ssl.py:1136, in SSLSocket.read(self, len, buffer)
#    1134         return self._sslobj.read(len, buffer)
#    1135     else:
# -> 1136         return self._sslobj.read(len)
#    1137 except SSLError as x:
#    1138     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# # Using the vectorDB

# %%
db= DB(llm)

# %%
vectordb = db.createDB()
# Out:
# # VectorDB: continue on the DB
# - 3208 elements already stored.
# - VectorDB: adding 2362 documents.

# %%
from futures.pages import PagesWriter

# %%
pw = PagesWriter(db=db)

# %%
pw.createPages_metaPrep()
# Out:
# 3208 elements already stored.
# (                                   src  \
#  0     12c665a21f8c6930a28f7c56f3b79b19
#  1     7a34820852cf03cbbdb1fb75ca3b629c
#  2     4dc27c3427b9c3021d4a20603e51e516
#  3     4a29bff5e6b05b4826468801ee240edb
#  4     6bac89b8c5fdf1c1e33c8e1da193827a
#  ...                                ...
#  2357  a6bfcabefea560d7dfefd5aab87f047c
#  2358  5d04744a3bee2ab6564f5e2ff60136d8
#  2359  037aba804501ec9f75f8bb434b8a6c20
#  2360  382e9ebc1e518ee49e541da1e6b5f8af
#  2361  6e0e074e3fd0d29800b270beffb6d3f3
#
#                                                  content      LEN
#  0     - A micro-retirement is a way for some young w...   4350.0
#  1     Yesterday Google ordered its entire North Amer...  20097.0
#  2     What is topoconductor, new state of matter cre...   1990.0
#  3     Quantum computing has enormous potential, but ...   3483.0
#  4     Construit avec une nouvelle classe de matériau...   1880.0
#  ...                                                 ...      ...
#  2357  Debashis Chanda had trouble finding a physicis...   2128.0
#  2358  Construct Knowledge Graphs From Unstructured T...  10422.0
#  2359  Learn In Public\nThe fastest way to learn\nswy...   9756.0
#  2360  It’s been a frenetic six months since OpenAI i...   4654.0
#  2361  Every two weeks from March to November, Chris ...  18469.0
#
#  [2362 rows x 3 columns],
#  Empty DataFrame
#  Columns: [name, description, change, 10-year, driving-force, relevancy, src]
#  Index: [])
